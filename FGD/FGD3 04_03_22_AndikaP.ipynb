# %%
# No. 1
def cetak_10x():
  for i in range(10):
    print(i+1, ' Belajar Python itu menyenangkan')

cetak_10x()
# Out:
# 1  Belajar Python itu menyenangkan
# 2  Belajar Python itu menyenangkan
# 3  Belajar Python itu menyenangkan
# 4  Belajar Python itu menyenangkan
# 5  Belajar Python itu menyenangkan
# 6  Belajar Python itu menyenangkan
# 7  Belajar Python itu menyenangkan
# 8  Belajar Python itu menyenangkan
# 9  Belajar Python itu menyenangkan
# 10  Belajar Python itu menyenangkan

# %%
# No. 2
def cetak_apapun_10x(teks):
  for i in range(10):
    print(i+1, teks)

cetak_apapun_10x('Belajar pemrograman dapat mengasah logika berfikir')
# Out:
# 1 Belajar pemrograman dapat mengasah logika berfikir
# 2 Belajar pemrograman dapat mengasah logika berfikir
# 3 Belajar pemrograman dapat mengasah logika berfikir
# 4 Belajar pemrograman dapat mengasah logika berfikir
# 5 Belajar pemrograman dapat mengasah logika berfikir
# 6 Belajar pemrograman dapat mengasah logika berfikir
# 7 Belajar pemrograman dapat mengasah logika berfikir
# 8 Belajar pemrograman dapat mengasah logika berfikir
# 9 Belajar pemrograman dapat mengasah logika berfikir
# 10 Belajar pemrograman dapat mengasah logika berfikir

# %%
# No. 3
def cetak_apapun_10x_dengan_input(teks):
  for i in range(10):
    print(i+1, teks)

inputnya = input()
cetak_apapun_10x_dengan_input(inputnya)
# Out:
# Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 1 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 2 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 3 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 4 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 5 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 6 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 7 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 8 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 9 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan
# 10 Cara terbaik belajar pemrograman adalah mempelajari teori diiringi praktek dan memperbanyak latihan

# %%
# No. 4
def cetak_apapun_10x_dengan_default(teks='Selamat belajar python, jangan lupa perbanyak latihan yaa'):
  for i in range(10):
    print(i+1, teks)

cetak_apapun_10x_dengan_default()
print()
cetak_apapun_10x_dengan_default("Oh senangnya, aku senang sekali :D")
# Out:
# 1 Selamat belajar python, jangan lupa perbanyak latihan yaa
# 2 Selamat belajar python, jangan lupa perbanyak latihan yaa
# 3 Selamat belajar python, jangan lupa perbanyak latihan yaa
# 4 Selamat belajar python, jangan lupa perbanyak latihan yaa
# 5 Selamat belajar python, jangan lupa perbanyak latihan yaa
# 6 Selamat belajar python, jangan lupa perbanyak latihan yaa
# 7 Selamat belajar python, jangan lupa perbanyak latihan yaa
# 8 Selamat belajar python, jangan lupa perbanyak latihan yaa
# 9 Selamat belajar python, jangan lupa perbanyak latihan yaa
# 10 Selamat belajar python, jangan lupa perbanyak latihan yaa
#
# 1 Oh senangnya, aku senang sekali :D
# 2 Oh senangnya, aku senang sekali :D
# 3 Oh senangnya, aku senang sekali :D
# 4 Oh senangnya, aku senang sekali :D
# 5 Oh senangnya, aku senang sekali :D
# 6 Oh senangnya, aku senang sekali :D
# 7 Oh senangnya, aku senang sekali :D
# 8 Oh senangnya, aku senang sekali :D
# 9 Oh senangnya, aku senang sekali :D
# 10 Oh senangnya, aku senang sekali :D

# %%
# No. 5
def hitung_luas_persegi(panjang_sisi):
  print(panjang_sisi*panjang_sisi)

hitung_luas_persegi(9.23)
# Out:
# 85.19290000000001

# %%
hitung_luas_persegi(12.0)
# Out:
# 144.0

# %%
hitung_luas_persegi(13)
# Out:
# 169

# %%
# No. 6
tanpa_kembalian = hitung_luas_persegi(10.3)
type(tanpa_kembalian)
# Out:
# 106.09000000000002
# NoneType

# %%
# No. 7
def hitung_luas_persegi_panjang(panjang,lebar):
  luas_persegi_panjang = panjang*lebar
  return luas_persegi_panjang

hitung_luas_persegi_panjang(5,8)
# Out:
# 40

# %%
hitung_luas_persegi_panjang(5.2,8.434)
# Out:
# 43.8568

# %%
# No. 8
dengan_kembalian = hitung_luas_persegi_panjang(5.2,8.434)
type(dengan_kembalian)
# Out:
# float

# %%
# No. 10
print(tanpa_kembalian)
print(dengan_kembalian)
# Out:
# None
# 43.8568
